# %%
Graph_nodes = {
'A': [('B', 6), ('F', 3)],
'B': [('C', 3), ('D', 2)],
'C': [('D', 1), ('E', 5)],
'D': [('C', 1), ('E', 8)],
'E': [('I', 5), ('J', 5)],
'F': [('G', 1), ('H', 7)],
'G': [('I', 3)],
'H': [('I', 2)],
'I': [('E', 5), ('J', 3)],
}

def get_neighbour(V):
    if V in Graph_nodes:
        return Graph_nodes[V]
    else:
        return None
    
def h(n):
    H_dist = {
    'A': 10,
    'B': 8,
    'C': 5,
    'D': 7,
    'E': 3,
    'F': 6,
    'G': 5,
    'H': 3,
    'I': 1,
    'J': 0
    }
    return H_dist[n]


def aStarAlgo(start_node , stop_node):

    open_set = set(start_node)
    closed_set = set()
    g={}
    parents={}
    g[start_node] =0
    parents[start_node] = start_node

    while len(open_set)>0:
        n=None

        for v in open_set:
            if n==None or g[v]+h(v) < g[n]+h(n):
                n=v
            
        if n==stop_node or Graph_nodes[n] == None:
            pass
        else:
            for(m,weight) in get_neighbour(n):
                if m not in open_set and m not in closed_set:
                    open_set.add(m)
                    parents[m] = n
                    g[m]=g[n]+weight
                
                else:
                    if g[m]>g[n]+weight:
                        g[m] =g[n]+weight
                        parents[m] = n
                        if m in closed_set:
                            closed_set.remove(m)
                            open_set.add(m)
        
        if n==None:
            print("Path does not exist !")
            return None
        
        if n==stop_node:
            path=[]

            while parents[n] != n:
                path.append(n)
                n=parents[n]
            
            path.append(start_node)

            path.reverse()

            print(path)
            return path
        
        open_set.remove(n)
        closed_set.add(n)

    print('Path does not exist!')
    return None

aStarAlgo('A','J')
# Out:
# ['A', 'F', 'G', 'I', 'J']
# ['A', 'F', 'G', 'I', 'J']

# %%
import heapq

Graph_nodes = {
'A': [('B', 6), ('F', 3)],
'B': [('C', 3), ('D', 2)],
'C': [('D', 1), ('E', 5)],
'D': [('C', 1), ('E', 8)],
'E': [('I', 5), ('J', 5)],
'F': [('G', 1), ('H', 7)],
'G': [('I', 3)],
'H': [('I', 2)],
'I': [('E', 5), ('J', 3)],
'J': []
}

def get_neighbour(v):
    return Graph_nodes.get(v, None)


def h(n):
    H_dist = {
        'A':10,'B':8,'C':5,'D':7,'E':3,
        'F':6,'G':5,'H':3,'I':1,'J':0
    }
    return H_dist[n]


def aStarAlgo(start_node, stop_node):

    open_queue = []
    heapq.heappush(open_queue, (0, start_node))

    closed_set = set()

    g = {}
    parents = {}

    g[start_node] = 0
    parents[start_node] = start_node

    while open_queue:

        f, n = heapq.heappop(open_queue)

        

        closed_set.add(n)

        for (m, weight) in get_neighbour(n):

            if m in closed_set:
                continue

            new_cost = g[n] + weight

            if m not in g or new_cost < g[m]:

                g[m] = new_cost
                parents[m] = n

                f_value = g[m] + h(m)

                heapq.heappush(open_queue, (f_value, m))
        
        if n == stop_node:

            path = []

            while parents[n] != n:
                path.append(n)
                n = parents[n]

            path.append(start_node)
            path.reverse()

            print("Path:", path)
            return path
        if n==None:
            print("Path does not exist")
            return None


aStarAlgo('A','J')
# Out:
# Path: ['A', 'F', 'G', 'I', 'J']
# ['A', 'F', 'G', 'I', 'J']

# %%
import heapq

goal = ((1,2,3),
        (4,5,6),
        (7,8,0))

def get_neighbour(state):

    neighbours = []

    # find blank
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                x,y = i,j

    moves = [(1,0),(-1,0),(0,1),(0,-1)]

    for dx,dy in moves:

        nx = x + dx
        ny = y + dy

        if 0 <= nx < 3 and 0 <= ny < 3:

            new_state = [list(row) for row in state]

            new_state[x][y],new_state[nx][ny] = new_state[nx][ny],new_state[x][y]

            neighbours.append((tuple(tuple(row) for row in new_state),1))

    return neighbours


def h(state):

    misplaced = 0

    for i in range(3):
        for j in range(3):
            if state[i][j] != 0 and state[i][j] != goal[i][j]:
                misplaced += 1

    return misplaced


def aStarAlgo(start_node, stop_node):

    open_queue = []
    heapq.heappush(open_queue, (0, start_node))

    closed_set = set()

    g = {}
    parents = {}

    g[start_node] = 0
    parents[start_node] = start_node

    while open_queue:

        f, n = heapq.heappop(open_queue)

        if n == stop_node:

            path = []

            while parents[n] != n:
                path.append(n)
                n = parents[n]

            path.append(start_node)
            path.reverse()

            for p in path:
                for row in p:
                    print(row)
                print()

            return path

        closed_set.add(n)

        for (m, weight) in get_neighbour(n):

            if m in closed_set:
                continue

            new_cost = g[n] + weight

            if m not in g or new_cost < g[m]:

                g[m] = new_cost
                parents[m] = n

                f_value = g[m] + h(m)

                heapq.heappush(open_queue, (f_value, m))


start = ((1,2,3),
         (4,0,6),
         (7,5,8))

aStarAlgo(start, goal)
# Out:
# (1, 2, 3)
# (4, 0, 6)
# (7, 5, 8)
#
# (1, 2, 3)
# (4, 5, 6)
# (7, 0, 8)
#
# (1, 2, 3)
# (4, 5, 6)
# (7, 8, 0)
# [((1, 2, 3), (4, 0, 6), (7, 5, 8)),
#  ((1, 2, 3), (4, 5, 6), (7, 0, 8)),
#  ((1, 2, 3), (4, 5, 6), (7, 8, 0))]

# %%
import heapq

grid = [
[0,0,0,0],
[1,1,0,1],
[0,0,0,0],
[0,1,1,0]
]

rows = len(grid)
cols = len(grid[0])

start = (0,0)
goal = (3,3)


def get_neighbour(node):

    r,c = node

    moves = [(1,0),(-1,0),(0,1),(0,-1)]

    neighbours = []

    for dr,dc in moves:

        nr = r + dr
        nc = c + dc

        if 0<=nr<rows and 0<=nc<cols and grid[nr][nc]==0:

            neighbours.append(((nr,nc),1))

    return neighbours


def h(n):

    return abs(n[0]-goal[0]) + abs(n[1]-goal[1])   # Manhattan distance


def aStarAlgo(start_node, stop_node):

    open_queue = []
    heapq.heappush(open_queue,(0,start_node))

    closed_set=set()

    g={}
    parents={}

    g[start_node]=0
    parents[start_node]=start_node

    while open_queue:

        f,n = heapq.heappop(open_queue)

        if n==stop_node:

            path=[]

            while parents[n]!=n:
                path.append(n)
                n=parents[n]

            path.append(start_node)
            path.reverse()

            print("Path:",path)
            return path

        closed_set.add(n)

        for (m,weight) in get_neighbour(n):

            if m in closed_set:
                continue

            new_cost = g[n] + weight

            if m not in g or new_cost < g[m]:

                g[m]=new_cost
                parents[m]=n

                f_value = g[m] + h(m)

                heapq.heappush(open_queue,(f_value,m))


aStarAlgo(start,goal)
# Out:
# Path: [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2), (2, 3), (3, 3)]
# [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2), (2, 3), (3, 3)]
